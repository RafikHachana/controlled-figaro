# %%
# !git clone https://github.com/dvruette/figaro.git
# !git clone https://github.com/RafikHachana/figaro.git
# !cd figaro && git checkout feature/alter_descriptions
# Out:
# fatal: destination path 'figaro' already exists and is not an empty directory.
# M	src/evaluate.py
# Already on 'feature/alter_descriptions'
# Your branch is up to date with 'origin/feature/alter_descriptions'.

# %%
# !cd figaro && git checkout feature/alter_descriptions
# Out:
# Already on 'feature/alter_descriptions'
# Your branch is up to date with 'origin/feature/alter_descriptions'.

# %%
# !pip install torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 55.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.1
#     Uninstalling torch-1.9.1:
#       Successfully uninstalled torch-1.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.1 requires torch==1.9.1, but you have torch 1.7.1 which is incompatible.
# torchmetrics 0.11.1 requires torch>=1.8.1, but you have torch 1.7.1 which is incompatible.
# ...

# %%
# GPU version
# !pip uninstall torch torchvision torchaudio -y
# !pip install torchvision==0.8.2
# !cd figaro && pip install -r requirements.txt
# Out:
# Found existing installation: torch 1.9.1
# Uninstalling torch-1.9.1:
#   Successfully uninstalled torch-1.9.1
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached torch-1.9.1-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.11 requires torchvision>=0.8.2, which is not installed.
# ...

# %% [markdown]
# ## CPU version of requirements

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torchvision==0.8.2
# !cd figaro && pip install -r requirements.txt
# Out:
# Found existing installation: torch 1.13.1+cu116
# Uninstalling torch-1.13.1+cu116:
#   Successfully uninstalled torch-1.13.1+cu116
# Found existing installation: torchvision 0.14.1+cu116
# Uninstalling torchvision-0.14.1+cu116:
#   Successfully uninstalled torchvision-0.14.1+cu116
# Found existing installation: torchaudio 0.13.1+cu116
# Uninstalling torchaudio-0.13.1+cu116:
#   Successfully uninstalled torchaudio-0.13.1+cu116
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 65.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 78.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 93.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 54.9 MB/s eta 0:00:00
# ...

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 54.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 62.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 KB 50.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.1
#     Uninstalling torch-1.9.1:
#       Successfully uninstalled torch-1.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !wget -O checkpoints.zip https://polybox.ethz.ch/index.php/s/a0HUHzKuPPefWkW/download
# !unzip checkpoints.zip
# Out:
# --2023-02-12 09:31:55--  https://polybox.ethz.ch/index.php/s/a0HUHzKuPPefWkW/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘checkpoints.zip’
#
# checkpoints.zip         [ <=>                ]   2.30G  12.1MB/s    in 3m 17s
#
# 2023-02-12 09:35:13 (12.0 MB/s) - ‘checkpoints.zip’ saved [2471127085]
#
# Archive:  checkpoints.zip
#    creating: checkpoints/
#  extracting: checkpoints/baseline.ckpt
#  extracting: checkpoints/figaro-expert.ckpt
#  extracting: checkpoints/figaro-learned.ckpt
#  extracting: checkpoints/figaro.ckpt
#  extracting: checkpoints/vq-vae.ckpt

# %%
# !wget http://hog.ee.columbia.edu/craffel/lmd/lmd_full.tar.gz
# !tar -xzf lmd_full.tar.gz
# Out:
# --2023-02-16 20:07:54--  http://hog.ee.columbia.edu/craffel/lmd/lmd_full.tar.gz
# Resolving hog.ee.columbia.edu (hog.ee.columbia.edu)... 128.59.66.5
# Connecting to hog.ee.columbia.edu (hog.ee.columbia.edu)|128.59.66.5|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1768163879 (1.6G) [application/x-gzip]
# Saving to: ‘lmd_full.tar.gz’
#
# lmd_full.tar.gz     100%[===================>]   1.65G  11.2MB/s    in 2m 30s
#
# 2023-02-16 20:10:25 (11.2 MB/s) - ‘lmd_full.tar.gz’ saved [1768163879/1768163879]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd figaro && git stash && git checkout HEAD~1
# Out:
# Saved working directory and index state WIP on alter_descriptions: 3860bb8 remove the vocab decoding
# Note: switching to 'HEAD~1'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at aed8db5 add debug output for time measurement

# %%
# !cd figaro && git stash && git pull
# Out:
# No local changes to save
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 8 (delta 6), reused 8 (delta 6), pack-reused 0
# Unpacking objects: 100% (8/8), 659 bytes | 329.00 KiB/s, done.
# From https://github.com/RafikHachana/figaro
#    4514379..bc32370  feature/alter_descriptions -> origin/feature/alter_descriptions
# Updating 4514379..bc32370
# Fast-forward
#  src/alter_description.py |  2 +-
#  src/utils.py             | 15 ++++++++-------
#  2 files changed, 9 insertions(+), 8 deletions(-)

# %%
# !cd figaro && git log

# %%
# !cd figaro && MODEL=figaro CHECKPOINT=../checkpoints/figaro.ckpt VAE_CHECKPOINT=../checkpoints/vq-vae.ckpt ROOT_DIR=../lmd_full/f MAX_ITER=8 MAX_N_FILES=1  python src/generate.py
# !cd figaro && MODEL=figaro CHECKPOINT=../drive/MyDrive/Thesis/figaro.ckpt VAE_CHECKPOINT=../drive/MyDrive/Thesis/vq-vae.ckpt ROOT_DIR=/content/drive/MyDrive/Thesis  python src/generate.py
# !cd figaro && MODEL=figaro CHECKPOINT=../drive/MyDrive/Thesis/figaro-expert.ckpt ROOT_DIR=/content/drive/MyDrive/Thesis ALTER_DESCRIPTION=False MAX_ITER=1599 python src/generate.py
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/imports.py", line 23, in <module>
#     import pkg_resources
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 3267, in <module>
#     def _initialize_master_working_set():
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 3302, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 613, in add_entry
#     for dist in find_distributions(entry, True):
# ...

# %% [markdown]
# ## Trying the altered description on the 1st dataset shared, with batch size

# %%
# !ls /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32/ | wc -l
# Out:
# 6942

# %%
# !cd figaro && MODEL=figaro CHECKPOINT=../drive/MyDrive/Thesis/figaro-expert.ckpt \
ROOT_DIR=/content/drive/MyDrive/Thesis/LakhDataset/lmd_clean/.004/ \
ALTER_DESCRIPTION=True \
MAX_ITER=4000 \
BATCH_SIZE=25 \
OUTPUT_DIR=/content/drive/MyDrive/Thesis/generated/lmd_clean/ \
python src/generate.py
# Out:
# 2023-02-24 06:41:46.825925: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-24 06:41:51.192384: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-24 06:41:51.192746: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# # EVAL !

# %%
# !cd figaro && git stash && git pull  && git submodule update --init
# Out:
# No local changes to save
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 376 bytes | 188.00 KiB/s, done.
# From https://github.com/RafikHachana/figaro
#    2825cc8..e81cd1c  feature/alter_descriptions -> origin/feature/alter_descriptions
# Updating 2825cc8..e81cd1c
# Fast-forward
#  src/evaluate.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# MusDr

# !cd figaro && \
SAMPLES_DIR=/content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset \
MAX_FILES=2 python3 src/eval_symbolic_musdr.py \
-s /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32 \
-o /content/drive/MyDrive/Thesis/musdr_eval_all.csv \
-n 30000
# Out:
# Streaming output truncated to the last 5000 lines.
#   GS: 0.9969
#   CPI: 0.8947
# ...
# >> now processing: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/Woman_in_Love.2__altered_mean_duration_(-21).mid
#   1-bar H: 1.773
#   4-bar H: 2.092
#   GS: 0.9898
#   CPI: 0.8000
# ...
# >> now processing: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/Woman_in_Love.2__altered_mean_pitch_(-20).mid
#   1-bar H: 2.258
#   4-bar H: 2.606
#   GS: 0.9958
#   CPI: 0.8750
# ...
# >> now processing: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/Woman_in_Love.2__altered_mean_pitch_(2).mid
#   1-bar H: 2.357
#   4-bar H: 2.700
#   GS: 1.0000
#   CPI: 0.9111
# ...
# >> now processing: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/Woman_in_Love.2__altered_mean_velocity_(-8).mid
#   1-bar H: 2.501
#   4-bar H: 2.876
#   GS: 1.0000
#   CPI: 0.8718
# ...

# %%
# !cd figaro && SAMPLES_DIR=/content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset MAX_FILES=2 python3 src/midi_to_musdr.py
# Out:
# ['Bar_1', 'Time Signature_3/4', 'Position_0', 'Chord_G#:maj', 'Position_0', 'Tempo_16', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_87', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_92', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_96', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_String Ensemble 2', 'Pitch_87', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_String Ensemble 2', 'Pitch_92', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_String Ensemble 2', 'Pitch_96', 'Velocity_12', 'Duration_19', 'Bar_2', 'Time Signature_3/4', 'Position_0', 'Chord_G#:maj', 'Position_0', 'Tempo_16', 'Position_0', 'Chord_C#:min', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_85', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_88', 'Velocity_12', 'Duration_19', 'Position_0', 'Instrument_Bright Acoustic Piano', 'Pitch_92', 'Veloci
# ...

# %%
# !cd figaro && SAMPLE_DIR=/content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset/ OUT_FILE=./eval.csv MAX_SAMPLES=20000 python src/evaluate.py

# %%
# lmd_clean/figaro/max_iter\=4000,max_bars\=32

# %%
# TODO: Output the previous thing to G-Drive, and sync the directory with this command

# FIGARO Eval
# !cd figaro && \
SAMPLE_DIR=/content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32 \
OUT_FILE=/content/drive/MyDrive/Thesis/eval_500.csv \
MAX_SAMPLES=500\
python src/evaluate.py
# Out:
# [info] Group 1/17299 | original: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/gt/1,_2,_3,_4_Sumpin_New_.mid | sample: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/1,_2,_3,_4_Sumpin_New_.mid
# [info] Group 1: inst_f1=0.98 | chord_f1=0.62 | pitch_oa=0.58 | vel_oa=0.03 | dur_oa=0.13 | chroma_sim=0.58 | groove_sim=0.63
# [info] Group 2/17299 | original: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/gt/1,_2,_3,_4_Sumpin_New___altered_mean_duration_(10).mid | sample: /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter=4000,max_bars=32/1,_2,_3,_4_Sumpin_New___altered_mean_duration_(10).mid
# [info] Group 2: inst_f1=0.96 | chord_f1=0.53 | pitch_oa=0.63 | vel_oa=0.03 | dur_oa=0.16 | chroma_sim=0.67 | groove_sim=0.65
# ...

# %% [markdown]
# ## Copying stuff to G Drive
#
# Already used, no need to run again

# %%
# !cp ./checkpoints/figaro.ckpt /content/drive/MyDrive/Thesis
# !cp ./checkpoints/figaro-expert.ckpt /content/drive/MyDrive/Thesis
# !cp ./checkpoints/figaro-learned.ckpt /content/drive/MyDrive/Thesis

# %%
# !cp ./lmd_full/0/0eb937be112abf86112badb0811aa1c2.mid .

# %%
# !cp ./checkpoints/vq-vae.ckpt /content/drive/MyDrive/Thesis

# %%
# !cp ./checkpoints/figaro-expert.ckpt /content/drive/MyDrive/Thesis

# %%
# !mkdir /content/drive/MyDrive/Thesis/lmd_0

# %%
# !cp -r ./lmd_full/0 /content/drive/MyDrive/Thesis/lmd_0

# %%
# !find ./figaro/samples/figaro/max_iter\=1400,max_bars\=32 -type f | wc -l
# Out:
# 640

# %%
# !ls /content/drive/MyDrive/Thesis/LakhDataset/lmd_clean | head -n 200 | xargs -I '{}' mv /content/drive/MyDrive/Thesis/LakhDataset/lmd_clean/{} /content/drive/MyDrive/Thesis/LakhDataset/lmd_clean/.001/

# %%
import os
import glob

# %% [markdown]
# ## Music quality evaluation

# %%
# !git clone git@github.com:slSeanWU/MusDr.git

# %%
# !ls /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32/ | grep "inst_(" |wc -l
# Out:
# 3063

# %%
# !mkdir /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset/gt/

# %%
# !ls /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32/gt/ | head -n 200 | xargs -I '{}' cp /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/max_iter\=4000,max_bars\=32/gt/{}  /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset/gt/

# %%
# !ls /content/drive/MyDrive/Thesis/generated/lmd_clean/figaro/subset/gt
# Out:
# '10,000_Promises__altered_mean_pitch_(4).mid'
#  10,000_Promises.mid
# '1000_Oceans__altered_mean_duration_(23).mid'
# '1000_Oceans__altered_mean_pitch_(-20).mid'
# '1000_Oceans__altered_mean_velocity_(-18).mid'
# '1000_Oceans__altered_note_density_(13).mid'
#  1000_Oceans.mid
#  1000_Oceans__remove_rand_inst.mid
# '1000_Oceans__transposed_chords_(18).mid'
# '1,_2,_3,_4_Sumpin_New___altered_mean_duration_(10).mid'
# '1,_2,_3,_4_Sumpin_New___altered_mean_pitch_(12).mid'
#  1,_2,_3,_4_Sumpin_New_.mid
#  1,_2,_3,_4_Sumpin_New___remove_rand_inst.mid
# '1,_2,_3,_4_Sumpin_New___transposed_chords_(-17).mid'
# '1950__altered_mean_duration_(20).mid'
# '1950__altered_mean_pitch_(24).mid'
# '1950__altered_mean_velocity_(9).mid'
#  1950.mid
# '2,000_Man__altered_mean_duration_(-28).mid'
# '2,000_Man__altered_mean_pitch_(8).mid'
# '2,000_Man__altered_mean_velocity_(29).mid'
# '2,000_Man__altered_note_density_(9).mid'
#  2,000_Man.mid
#  2,000_Man__remove_rand_inst.mid
# ...
