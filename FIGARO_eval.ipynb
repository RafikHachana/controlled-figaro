# %%
# !git clone https://github.com/RafikHachana/figaro.git
# !cd figaro && git checkout feature/alter_descriptions
# Out:
# Cloning into 'figaro'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 154 (delta 92), reused 137 (delta 86), pack-reused 2
# Receiving objects: 100% (154/154), 51.72 KiB | 897.00 KiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Branch 'feature/alter_descriptions' set up to track remote branch 'feature/alter_descriptions' from 'origin'.
# Switched to a new branch 'feature/alter_descriptions'

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torchvision==0.8.2
# !cd figaro && pip install -r requirements.txt
# Out:
# Found existing installation: torch 1.13.1+cu116
# Uninstalling torch-1.13.1+cu116:
#   Successfully uninstalled torch-1.13.1+cu116
# Found existing installation: torchvision 0.14.1+cu116
# Uninstalling torchvision-0.14.1+cu116:
#   Successfully uninstalled torchvision-0.14.1+cu116
# Found existing installation: torchaudio 0.13.1+cu116
# Uninstalling torchaudio-0.13.1+cu116:
#   Successfully uninstalled torchaudio-0.13.1+cu116
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 60.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 74.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 73.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 44.3 MB/s eta 0:00:00
# ...

# %%
# !cd figaro && SAMPLE_DIR=/content/drive/MyDrive/Thesis/generated/figaro/max_iter=10000,max_bars=32 python src/evaluate.py
# Out:
# [info] Group 1/64 | original: /content/drive/MyDrive/Thesis/generated/figaro/max_iter=10000,max_bars=32/gt/00ca8cc679377059e9d5dd6165c92d19.mid | sample: /content/drive/MyDrive/Thesis/generated/figaro/max_iter=10000,max_bars=32/00ca8cc679377059e9d5dd6165c92d19.mid
# [info] Group 1: inst_f1=0.99 | chord_f1=0.87 | pitch_oa=0.52 | vel_oa=0.54 | dur_oa=0.51 | chroma_sim=0.91 | groove_sim=0.74
# [info] Group 2/64 | original: /content/drive/MyDrive/Thesis/generated/figaro/max_iter=10000,max_bars=32/gt/00d730aefda19ec6295dc9b6d17c5d6e.mid | sample: /content/drive/MyDrive/Thesis/generated/figaro/max_iter=10000,max_bars=32/00d730aefda19ec6295dc9b6d17c5d6e.mid
# [info] Group 2: inst_f1=0.97 | chord_f1=0.41 | pitch_oa=0.81 | vel_oa=0.54 | dur_oa=0.33 | chroma_sim=0.44 | groove_sim=0.49
# ...

# %%
# !ls /content/drive/MyDrive/Thesis/lmd_0/0 | wc -l
# Out:
# 10344
